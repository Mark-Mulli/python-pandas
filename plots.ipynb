# %%
import pandas as pd

#library for creating plots
import matplotlib.pyplot as plt

#index_col defines the column which is used as an index in the dataframe and parse_dates converts the dates to a timestamp object
file = pd.read_csv('/Users/markmulli/Downloads/air_quality_no2.csv',index_col=0,parse_dates=True)

file
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
# ...                              ...            ...             ...
# 2019-06-20 22:00:00              NaN           21.4             NaN
# 2019-06-20 23:00:00              NaN           24.9             NaN
# 2019-06-21 00:00:00              NaN           26.5             NaN
# 2019-06-21 01:00:00              NaN           21.8             NaN
# 2019-06-21 02:00:00              NaN           20.0             NaN
#
# [1035 rows x 3 columns]

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1035 entries, 2019-05-07 02:00:00 to 2019-06-21 02:00:00
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   station_antwerp  95 non-null     float64
#  1   station_paris    1004 non-null   float64
#  2   station_london   969 non-null    float64
# dtypes: float64(3)
# memory usage: 32.3 KB

# %%
file.plot()
plt.show()

# %%
file['station_paris'].plot()
plt.show()

# %%
file.plot.scatter(x='station_london',y='station_paris',alpha =0.5)
plt.show()

# %%
#plot methods
for m in dir(file.plot):
    #print(m)
    if not m.startswith('_'):
        print(m)
# Out:
# area
# bar
# barh
# box
# density
# hexbin
# hist
# kde
# line
# pie
# scatter

# %%
file.plot.box()
plt.show()

# %%
#split each to its own graph
axs = file.plot.area(figsize = (12,3), subplots=True)
plt.show()

# %%
#create empty matplotlib figure and axes
fig, axs = plt.subplots(figsize = (12,4))
#put the area plot on the prepared figure
file.plot.area(ax=axs)
#customization
axs.set_ylabel('Y label')
#display the plot
plt.show()
