# %%
#import pandas library
import pandas as pd

#create a new series
column_one = pd.Series([1,2,3,4,'five'], name = 'column one')
#read excel file as a dataframe
file_path = 'res/'
df = pd.read_excel(f'{file_path}filename.xlsx')
#fill excel with values
df['Vehicle Class'] = df['Vehicle Class'].fillna(method="ffill", axis=0)

#view all columns
print(df.columns)

#display the dataframe
print(df)

#Series of vehicle class
print(df['Vehicle Class'])

#displays the value that meets at the row with an integer location of 4 and column with an integer location of 6
print(df.iloc[4, 6])

#an iterative statement for looping through rows
for i, row in df.iterrows():
    print(i, row[['Exit Description', 'Vehicle Class']])

#finds all rows where the column exit description is equal to 'Wellington: US-160'
print(df.loc[df['Exit Description']=='123456789'])

#finds all rows where the column Vehicle description is equal to 'Class 2'
print(df.loc[df['Vehicle Class']=='Class 2'])

#method describe used to find statistics of the data frame
print(df.describe())

#read excel file as a dataframe
df = pd.read_excel(f'{file_path}filename.xlsx')


#a function in pandas that sorts a series in order
variable = df.sort_values('Exit Description', ascending=False)

#returns the first five rows in a dataframe
print(var.head(5))

#returns a column payment and is assigned a variable to it
pay = df['Payment']
print(pay)

#modify a column
df.columns = ['first_col','last_col']
#change the columns to uppercase letters

df.columns = [x.upper() for x in df.columns]

rename columns
df.rename(columns = {'first_col':'first','last_col':'last'})

#grab some information about a particular data
df['first'].apply(len)
#function that converts a certain series to uppercase
def update(last):
	last.upper()
#Output the data frame
df['last'] = df['last'].apply(update)
df
#convert to lower case
df['last'] = df['last'].apply(lambda x: x.lower())
#defines location of a dataframe
print(df.loc[4, 'Payment'])
